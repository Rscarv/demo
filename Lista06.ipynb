# %% [markdown]
# <a href="https://colab.research.google.com/github/Rscarv/demo/blob/master/Lista06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Rômullo Souza de Carvalho (20114290100)
# Lista 6

#Questão 01
print('Questão 01')
import pandas as pd
dados = {'Matemática': [60, 58, 73, 51, 54, 75, 48, 72, 75, 83, 62, 52], 
         'Música': [80, 62, 70, 83, 62, 92, 79, 88, 54, 82, 64, 69]}
a = pd.DataFrame (dados, columns = ['Matemática','Música'])
Correlação = a.corr()
print(Correlação)
print( )
# Com a criação da váriavel "dados", usamos essa váriavel para calcularmos a correlação e encontramos o resultado do coeficiente r

#Questão 02
print('Questão 02')
print('a) Um número positivo ou negativo de 0 a 0,3 indica correlação desprezível, portanto, a relação entre a idade da versão e o número de páginas é desprezível pois o valor foi de 0,207.')
print( )

#Questão 03
print('Questão 03')
import pandas as pd 
dados = {'x': [2, 3, 4, 5, 4, 6, 7, 8, 8, 10], 
         'y': [48, 50, 56, 52, 43, 60, 62, 58, 64, 72]}
a = pd.DataFrame (dados, columns = ['x','y'])
Correlação = a.corr()
print(Correlação)
print( )
# Com a criação da váriavel "dados", usamos essa váriavel para calcularmos a correlação e encontramos o resultado do coeficiente de correlação.

#Questão 4
print('Questão 04')
import pandas as pd 
dados = {'x': [12, 16, 18, 20, 28, 30, 40, 48, 50, 54], 'y': [7.2, 7.4, 7.0, 6.5, 6.6, 6.7, 6.0, 5.6, 6.0, 5.5]}
a = pd.DataFrame (dados, columns = ['x','y'])
Correlação = a.corr()
print(Correlação)
print( )
# Com a criação da váriavel "dados", usamos essa váriavel para calcularmos a correlação e encontramos o resultado do coeficiente de correlação.

#Questão 05
print('Questão 05')
#Conjunto 1
print('Conjunto 01')
import statistics
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
# a)
print('a)')
print('A Média de X:', statistics.mean(x),'E A Média de Y:', round(statistics.mean(y),1))
print('O Desvio de X:', round(statistics.stdev(x),2),'E o Desvio Padrão de Y:', round(statistics.stdev(y),1))
print( )

# b)
print('b)')
import pandas as pd
dados = {'x': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y': [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]}
a = pd.DataFrame (dados, columns = ['x','y'])
Correlação = a.corr()
print('O Coeficiente de Corellação de X e Y:', Correlação)
print( )

#Conjunto 2
print('Conjunto 02')
import statistics
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
# a)
print('a)')
print('A Média de X:', statistics.mean(x),'E A Média de Y:', round(statistics.mean(y),1))
print('O Desvio Padrão de X:', round(statistics.stdev(x),2),'E o Desvio Padrão de Y:', round(statistics.stdev(y),1))
print( )

# b)
print('b)')
import pandas as pd
dados = {'x': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y': [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]}
a = pd.DataFrame (dados, columns = ['x','y'])
Correlação = a.corr()
print('O Coeficiente de Correlação de X e Y:', Correlação)
print( )

#Conjunto 3
print('Conjunto 03')
import statistics
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
# a)
print('a)')
print('A Média de X:', statistics.mean(x),'E a Média de Y:', round(statistics.mean(y),1))
print('O Desvio Padrão X:', round(statistics.stdev(x),2),'E o Desvio Padrão Y:', round(statistics.stdev(y),1))
print( )

# b)
print('b)')
import pandas as pd
dados = {'x': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y': [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]}
a = pd.DataFrame (dados, columns = ['x','y'])
Correlação = a.corr()
print('O Coeficiente de Correlação de X e Y:', Correlação)
print( )

#Conjunto 4
print('Conjunto 04')
import statistics
x = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]
# a)
print('a)')
print('A Média de X:', statistics.mean(x),'E A Média de Y:', round(statistics.mean(y),2))
print('O Desvio Padrão de X:', round(statistics.stdev(x),1),'E O Desvio Padrão de Y:', round(statistics.stdev(y),1))
print( )

# b)
print('b)')
import pandas as pd
dados = {'x': [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8], 'y': [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]}
a = pd.DataFrame (dados, columns = ['x','y'])
Correlação = a.corr()
print('O Coeficiente de Correlação  de X e Y:', Correlação)
print( )

# Com a criação da váriavel "dados" e seus valores de "x" e "y", usamos essa váriavel e seus valores para calcularmos a média e o desvio padrão de cada conjunto na questão a), e na questão b) calculamos o coeficiente de correlação de cada conjunto.

#Questão 6
print('Questão 05')
import pandas as pd
dados = {'Produtividade': [100, 102, 105, 108, 112, 120], 'Alimentação': [4, 5, 1, 3, 6, 2]}
a = pd.DataFrame (dados, columns = ['Produtividade','Alimentação'])
Correlação = a.corr()
print('O Coeficiente de Correlação Linear:')
print(Correlação)
print( )
# O diagrama do coeficiente de correlação entre produtividade e alimentação está correto, pois neste diagrama é apresentada a diminuição da alimentação em relação à produtividade e, no cálculo esse valor corresponde a uma correlação fraca e desprezível com o valor igual a: -0,196822.

import pandas as pd
dados = {'Produtividade': [100, 102, 105, 108, 112, 120], 'Exercícios': [1, 3, 2, 4, 5, 6]}
a = pd.DataFrame (dados, columns = ['Produtividade','Exercícios'])
Correlação = a.corr()
print('O Coeficiente de Correlação Linear:')
print(Correlação)
print( )
# O diagrama do coeficiente de correlação entre produtividade e exercício está correto, pois no diagrama mostra o aumento da produtividade relacionada ao exercício, e o cálculo mostra que esse valor corresponde a uma correlação positiva forte com o valor igual a: 0,925791.

import pandas as pd
dados = {'Produtividade': [100, 102, 105, 108, 112, 120], 'Rodízio': [3, 1, 2, 6, 4, 5]}
a = pd.DataFrame (dados, columns = ['Produtividade','Rodízio'])
Correlação = a.corr()
print('O Coeficiente de Correlação Linear:')
print(Correlação)
# O diagrama do coeficiente de correlação entre produtividade e rodízio está correto, pois no diagrama mostra o aumento do rodízio em relação à produtividade, e mostra no cálculo que este valor corresponde a uma correlação positiva média com o valor de: 0,634204.

# Com a criação da váriavel "dados", usamos essa váriavel para calcularmos o coeficiente de correlação linear de pearson em três casos diferentes e encontramos o seu resultado.
# Out:
# Questão 01
#             Matemática    Música
# Matemática    1.000000  0.169146
# Música        0.169146  1.000000
#
# Questão 02
# a) Um número positivo ou negativo de 0 a 0,3 indica correlação desprezível, portanto, a relação entre a idade da versão e o número de páginas é desprezível pois o valor foi de 0,207.
#
# Questão 03
#           x         y
# x  1.000000  0.876795
# y  0.876795  1.000000
#
# Questão 04
#           x         y
# x  1.000000 -0.940463
# y -0.940463  1.000000
#
# Questão 05
# Conjunto 01
# a)
# A Média de X: 9 E A Média de Y: 7.5
# O Desvio de X: 3.32 E o Desvio Padrão de Y: 2.0
#
# b)
# O Coeficiente de Corellação de X e Y:           x         y
# x  1.000000  0.816421
# y  0.816421  1.000000
#
# Conjunto 02
# a)
# A Média de X: 9 E A Média de Y: 7.5
# O Desvio Padrão de X: 3.32 E o Desvio Padrão de Y: 2.0
#
# b)
# O Coeficiente de Correlação de X e Y:           x         y
# x  1.000000  0.816237
# y  0.816237  1.000000
#
# Conjunto 03
# a)
# ...

# %% [markdown]
# # Nova seção
